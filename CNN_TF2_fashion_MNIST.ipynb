# %%
""" Simple CNN implementation with TensorFlow 2.0 for fashion MNIST dataset.
Author: Askery Canabarro 
Tested with TF 2.3.0
"""

# STEP 0: Import TensorFlow and dependencies/libraries.
import numpy as np
import pandas as pd
import random
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.layers import Input, Conv2D, Dense, Flatten, Dropout, MaxPooling2D
from tensorflow.keras.models import Model
print ("TF version: ", tf.__version__)
# Out:
# Bad key "text.kerning_factor" on line 4 in
# /home/askery/anaconda3/envs/tf2.3/lib/python3.6/site-packages/matplotlib/mpl-data/stylelib/_classic_test_patch.mplstyle.
# You probably need to get an updated matplotlibrc file from
# https://github.com/matplotlib/matplotlib/blob/v3.1.3/matplotlibrc.template
# or from the matplotlib source distribution
# TF version:  2.3.0

# %%
# STEP 1: Load the Fashion MNIST dataset.
(X_train,y_train),(X_test,y_test) = tf.keras.datasets.fashion_mnist.load_data()

# %%
# STEP 1a: Inspect type and shapes.
print ("Data type     ", type(X_train)) # numpy array. Nice!
print ("Xtrain shape: ", X_train.shape) # 60000 examples, 28 x 28 = 784 shape
print ("Xtest shape:  ", X_test.shape)  # 10000 examples, 28 x 28 = 784 shape
print ("ytrain shape: ", y_train.shape)
print ("ytest  shape: ", y_test.shape)
# Out:
# Data type      <class 'numpy.ndarray'>
# Xtrain shape:  (60000, 28, 28)
# Xtest shape:   (10000, 28, 28)
# ytrain shape:  (60000,)
# ytest  shape:  (10000,)

# %%
# STEP 1b: EDA
# print(X_train[0]), print(y_train[0])  # raw data
i = random.choice(list(range(len(X_train))))
plt.imshow(X_train[i], cmap='gray')     # example of the data with black background
plt.axis('off')
plt.title('black background')
plt.show()

# %%
# STEP 1c: Preprocessing. 

# Rescale the images pixels from range [0,255] to range [0.0,1.0].
X_train = X_train/255
X_test  = X_test/255

# TensorFlow likes cube of data!!!
X_train = X_train.reshape((-1,28,28,1)) # 60000 instances with 28x28x1 shape
X_test  = X_test.reshape((-1,28,28,1))  # 10000 instances with 28x28x1 shape

# %%
# STEP 2: build the model (functional API)
K = len (set(y_train) )             # number of classes

# CNN for feature extraction
i = Input(shape = X_train[0].shape) # 28x28x1: all inputs have the same shape, get the shape of the first one.
x = Conv2D(  32, [3,3], activation='relu')(i)
x = Conv2D(  64, [3,3], activation='relu')(x)
x = MaxPooling2D(pool_size=(2, 2))(x)
x = Dropout(0.25)(x)

# usual MLP
x = Flatten()(x)
x = Dense(128,activation='relu')(x)
x = Dropout(0.5)(x)
x = Dense(K,activation='softmax')(x)

model = Model(i,x)
print(model.summary())
# Out:
# Model: "functional_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 28, 28, 1)]       0
# _________________________________________________________________
# conv2d (Conv2D)              (None, 26, 26, 32)        320
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 24, 24, 64)        18496
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 12, 12, 64)        0
# _________________________________________________________________
# dropout (Dropout)            (None, 12, 12, 64)        0
# _________________________________________________________________
# flatten (Flatten)            (None, 9216)              0
# _________________________________________________________________
# dense (Dense)                (None, 128)               1179776
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 10)                1290
# =================================================================
# Total params: 1,199,882
# Trainable params: 1,199,882
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
# optimization and loss parameters
opt  = "adam"
loss = "sparse_categorical_crossentropy" #multiclasses!!

model.compile(optimizer=opt,
              loss=loss,
              metrics=['accuracy'])

# %%
# STEP 3: Train the model.
r = model.fit(X_train,y_train, 
          validation_data=(X_test,y_test), 
          epochs=25)
# Out:
# Epoch 1/25
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x7f35805c4598> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x7f35805c4598> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 1873/1875 [============================>.] - ETA: 0s - loss: 0.4792 - accuracy: 0.8304WARNING:tensorflow:AutoGraph could not transform <function Model.make_test_function.<locals>.test_function at 0x7f3588050268> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_test_function.<locals>.test_function at 0x7f3588050268> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.4789 - accuracy: 0.8305 - val_loss: 0.3232 - val_accuracy: 0.8841
# Epoch 2/25
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.3228 - accuracy: 0.8846 - val_loss: 0.2660 - val_accuracy: 0.9032
# Epoch 3/25
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.2730 - accuracy: 0.9009 - val_loss: 0.2461 - val_accuracy: 0.9080
# Epoch 4/25
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.2455 - accuracy: 0.9111 - val_loss: 0.2324 - val_accuracy: 0.9182
# Epoch 5/25
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.2209 - accuracy: 0.9190 - val_loss: 0.2456 - val_accuracy: 0.9121
# Epoch 6/25
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.2023 - accuracy: 0.9251 - val_loss: 0.2208 - val_accuracy: 0.9206
# Epoch 7/25
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.1870 - accuracy: 0.9300 - val_loss: 0.2380 - val_accuracy: 0.9209
# Epoch 8/25
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.1747 - accuracy: 0.9353 - val_loss: 0.2290 - val_accuracy: 0.9232
# Epoch 9/25
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.1641 - accuracy: 0.9386 - val_loss: 0.2287 - val_accuracy: 0.9212
# Epoch 10/25
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.1525 - accuracy: 0.9417 - val_loss: 0.2269 - val_accuracy: 0.9266
# Epoch 11/25
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.1468 - accuracy: 0.9441 - val_loss: 0.2477 - val_accuracy: 0.9227
# Epoch 12/25
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.1392 - accuracy: 0.9470 - val_loss: 0.2291 - val_accuracy: 0.9298
# Epoch 13/25
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.1335 - accuracy: 0.9489 - val_loss: 0.2258 - val_accuracy: 0.9301
# Epoch 14/25
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.1263 - accuracy: 0.9519 - val_loss: 0.2475 - val_accuracy: 0.9262
# Epoch 15/25
# 1875/1875 [==============================] - 7s 3ms/step - loss: 0.1235 - accuracy: 0.9536 - val_loss: 0.2382 - val_accuracy: 0.9287
# Epoch 16/25
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.1196 - accuracy: 0.9544 - val_loss: 0.2651 - val_accuracy: 0.9271
# Epoch 17/25
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.1128 - accuracy: 0.9576 - val_loss: 0.2604 - val_accuracy: 0.9258
# Epoch 18/25
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.1110 - accuracy: 0.9578 - val_loss: 0.2484 - val_accuracy: 0.9291
# Epoch 19/25
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.1079 - accuracy: 0.9602 - val_loss: 0.2514 - val_accuracy: 0.9308
# Epoch 20/25
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.1042 - accuracy: 0.9610 - val_loss: 0.2835 - val_accuracy: 0.9272
# Epoch 21/25
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.0997 - accuracy: 0.9620 - val_loss: 0.2776 - val_accuracy: 0.9258
# Epoch 22/25
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.0969 - accuracy: 0.9626 - val_loss: 0.2977 - val_accuracy: 0.9277
# Epoch 23/25
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.0936 - accuracy: 0.9643 - val_loss: 0.2834 - val_accuracy: 0.9301
# Epoch 24/25
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.0956 - accuracy: 0.9646 - val_loss: 0.2881 - val_accuracy: 0.9301
# Epoch 25/25
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.0917 - accuracy: 0.9650 - val_loss: 0.2730 - val_accuracy: 0.9333

# %%
# STEP 3a: See loss and accuracy in function of epochs
# Loss
plt.plot(r.history['loss'], label ='train loss')
plt.plot(r.history['val_loss'], label ='val loss')
plt.xlabel('epoch')
plt.ylabel('loss')
plt.legend()

# %%
# Accuracy
plt.plot(r.history['accuracy'], label ='train acc')
plt.plot(r.history['val_accuracy'], label ='val acc')
plt.xlabel('epoch')
plt.ylabel('acc')
plt.legend()

# %%
# STEP 4: Evaluate your model.
print("Test acc:", model.evaluate(X_test,y_test)[1])
# Out:
# 313/313 [==============================] - 1s 2ms/step - loss: 0.2730 - accuracy: 0.9333
# Test acc: 0.9333000183105469

# %%
# STEP 4a: Deeper evaluate your model.
inv  = model.predict(X_test)
inv  = np.array ( list (map(np.argmax, inv)) ) 

from sklearn.metrics import confusion_matrix, plot_confusion_matrix
clas   = ['T-shirt','Trouser','Pullover','Dress','Coat','Sandal','Shirt','Skeaker','Bag','Ankle Boot']
preds  = model.predict(X_test)
P      = np.array ( list (map(np.argmax, preds)) )
cm     = confusion_matrix(P,y_test)
df_cm  = pd.DataFrame(cm, index = clas, columns = clas, dtype='int32')

import seaborn as sn
plt.figure(figsize=(9,7))
sn.set(font_scale=1.4) 
sn.heatmap(df_cm, annot=True, annot_kws={"size": 10}) 
plt.show()

# %%
# STEP 4b: even deeper evaluation. Check misclassification example. Is it acceptable?
ind_err = np.array ( np.where(P != y_test) ).flatten() # getting indices where prediction differs from actual class
ind     = np.random.choice(ind_err)
plt.imshow(X_test[ind].reshape((28,28)), cmap = "gray")
plt.title ("Pred: " + str(clas[P[ind]]) + ", True: " + str(clas[y_test[ind]]))
plt.grid(False)
plt.show()
# Would you miss too?
